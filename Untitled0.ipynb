# %% [markdown]
# <a href="https://colab.research.google.com/github/Mitritch70/ForHomeWork_Git/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
import seaborn as sns

# %%
import random

# %%
df = pd.read_csv('sample_data/california_housing_test.csv')

# %%
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.05     37.37                27.0       3885.0           661.0
# 1    -118.30     34.26                43.0       1510.0           310.0
# 2    -117.81     33.78                27.0       3589.0           507.0
# 3    -118.36     33.82                28.0         67.0            15.0
# 4    -119.67     36.33                19.0       1241.0           244.0
#
#    population  households  median_income  median_house_value
# 0      1537.0       606.0         6.6085            344700.0
# 1       809.0       277.0         3.5990            176500.0
# 2      1484.0       495.0         5.7934            270500.0
# 3        49.0        11.0         6.1359            330000.0
# 4       850.0       237.0         2.9375             81700.0

# %%
df.shape
# Out:
# (3000, 9)

# %%
df.dtypes
# Out:
# longitude             float64
# latitude              float64
# housing_median_age    float64
# total_rooms           float64
# total_bedrooms        float64
# population            float64
# households            float64
# median_income         float64
# median_house_value    float64
# dtype: object

# %%
df. isnull().sum()
# Out:
# longitude             0
# latitude              0
# housing_median_age    0
# total_rooms           0
# total_bedrooms        0
# population            0
# households            0
# median_income         0
# median_house_value    0
# dtype: int64

# %%
df[df['median_income'] < 2]['median_house_value']
# Out:
# 5        67000.0
# 6        67000.0
# 16      181300.0
# 28      350000.0
# 43       79300.0
#           ...
# 2943     57200.0
# 2964     91300.0
# 2985    109400.0
# 2986     85400.0
# 2995    225000.0
# Name: median_house_value, Length: 360, dtype: float64

# %%
df.columns
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'median_house_value'],
#       dtype='object')

# %%
df.columns[:2]
# Out:
# Index(['longitude', 'latitude'], dtype='object')

# %%
for i in df.columns[:2]:
  print(df[i])
# Out:
# 0      -122.05
# 1      -118.30
# 2      -117.81
# 3      -118.36
# 4      -119.67
#          ...
# 2995   -119.86
# 2996   -118.14
# 2997   -119.70
# 2998   -117.12
# 2999   -119.63
# Name: longitude, Length: 3000, dtype: float64
# 0       37.37
# 1       34.26
# 2       33.78
# 3       33.82
# 4       36.33
#         ...
# 2995    34.42
# 2996    34.06
# 2997    36.30
# 2998    34.10
# 2999    34.42
# Name: latitude, Length: 3000, dtype: float64

# %%
df[((df['housing_median_age'] < 20) & (df['median_house_value'] > 7000))]['population']
# Out:
# 4        850.0
# 7       1341.0
# 8       1446.0
# 13      1935.0
# 16       189.0
#          ...
# 2981    2307.0
# 2984    2751.0
# 2985     642.0
# 2991     780.0
# 2997     693.0
# Name: population, Length: 830, dtype: float64

# %%
df.describe()
# Out:
#          longitude    latitude  housing_median_age   total_rooms  \
# count  3000.000000  3000.00000         3000.000000   3000.000000
# mean   -119.589200    35.63539           28.845333   2599.578667
# std       1.994936     2.12967           12.555396   2155.593332
# min    -124.180000    32.56000            1.000000      6.000000
# 25%    -121.810000    33.93000           18.000000   1401.000000
# 50%    -118.485000    34.27000           29.000000   2106.000000
# 75%    -118.020000    37.69000           37.000000   3129.000000
# max    -114.490000    41.92000           52.000000  30450.000000
#
#        total_bedrooms    population  households  median_income  \
# count     3000.000000   3000.000000  3000.00000    3000.000000
# mean       529.950667   1402.798667   489.91200       3.807272
# std        415.654368   1030.543012   365.42271       1.854512
# min          2.000000      5.000000     2.00000       0.499900
# ...

# %%
df['median_house_value'].min()
# Out:
# 22500.0

# %%
df['median_house_value'].max()
# Out:
# 500001.0

# %%
df[df['median_income'] == 3.1250]['median_house_value'].max()
# Out:
# 233300.0

# %%
df['median_house_value'].min()
# Out:
# 22500.0

# %%
df[df['median_house_value'] == df['median_house_value'].min()]['population'].max()
# Out:
# 1230.0

# %%
df[df['population']<500]
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 3       -118.36     33.82                28.0         67.0            15.0
# 15      -117.99     33.81                42.0        161.0            40.0
# 16      -120.81     37.53                15.0        570.0           123.0
# 34      -118.32     33.94                38.0       1067.0           170.0
# 51      -119.42     35.97                21.0        554.0           121.0
# ...         ...       ...                 ...          ...             ...
# 2929    -117.23     32.74                16.0        735.0           139.0
# 2947    -123.02     38.81                35.0        956.0           213.0
# 2960    -117.89     33.60                36.0       1496.0           247.0
# 2992    -122.33     37.39                52.0        573.0           102.0
# 2998    -117.12     34.10                40.0         96.0            14.0
#
#       population  households  median_income  median_house_value
# ...

# %%
df[df['population'] == df['population'].min()]['households'].max()
# Out:
# 3.0

# %%
sns.scatterplot(data=df, x = 'households', y = 'population')
# Out:
# <Axes: xlabel='households', ylabel='population'>

# %%
sns.relplot(data=df, x = 'longitude', y = 'median_house_value', kind='line')

# %%
sns.histplot(data=df, x = 'housing_median_age')
# Out:
# <Axes: xlabel='housing_median_age', ylabel='Count'>

# %%
sns.displot(data=df, x = 'median_house_value', hue='housing_median_age')

# %%
df_p = sns.load_dataset('penguins')

# %%
df_p.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %%
sns.scatterplot(data=df_p, x = 'bill_length_mm', y = 'bill_depth_mm', hue = 'sex')
# Out:
# <Axes: xlabel='bill_length_mm', ylabel='bill_depth_mm'>

# %%
sns.scatterplot(data=df_p, x = 'body_mass_g', y = 'flipper_length_mm', hue = 'sex')
# Out:
# <Axes: xlabel='body_mass_g', ylabel='flipper_length_mm'>

# %%
sns.scatterplot(data=df_p, x = 'bill_depth_mm', y = 'bill_length_mm', hue = 'body_mass_g', size=7)
# Out:
# <Axes: xlabel='bill_depth_mm', ylabel='bill_length_mm'>

# %%
list1=['bill_length_mm', 'bill_depth_mm', 'flipper_length_mm', 'body_mass_g', 'sex']
g = sns.PairGrid(df_p[list1])
g.map(sns.scatterplot)

# %%
sns.histplot(data=df_p, x = 'bill_length_mm')
# Out:
# <Axes: xlabel='bill_length_mm', ylabel='Count'>

# %%
sns.histplot(data=df_p, x = 'flipper_length_mm')
# Out:
# <Axes: xlabel='flipper_length_mm', ylabel='Count'>

# %%
df_p.loc[df_p['bill_length_mm'] >= 42, 'heidht_group'] = 'high'
df_p.loc[df_p['bill_length_mm'] < 35, 'heidht_group'] = 'low'
df_p.loc[((df_p['bill_length_mm'] >= 35) & (df_p['bill_length_mm'] < 42)), 'heidht_group'] = 'medium'

# %%
df_p.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex heidht_group
# 0       3750.0    Male       medium
# 1       3800.0  Female       medium
# 2       3250.0  Female       medium
# 3          NaN     NaN          NaN
# 4       3450.0  Female       medium

# %%
sns.displot(data=df_p, x = 'flipper_length_mm', hue='heidht_group')

# %%
sns.displot(data=df_p, x = 'body_mass_g', hue='heidht_group' )

# %%
lst = ['robot'] * 10
lst = ['human'] * 10
random.shuffle(lst)
data=pd.DataFrame({'whoAmI': lst})
data.head()
# Out:
#   whoAmI
# 0  human
# 1  human
# 2  human
# 3  human
# 4  human

# %%
data['tmp'] = 1

# %%
data.set_index([data.index, 'whoAmI'], inplace = True)

# %%
data = data.unstack(level = - 1, fill_value = 0).astype(int)

# %%
data.columns = data.columns.droplevel()

# %%
data.columns.name= None

# %%
data.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: [0, 1, 2, 3, 4]
